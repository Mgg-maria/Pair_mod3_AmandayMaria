# %%
import pandas as pd


import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
df = pd.read_csv("world_data_full_apply_nulos.csv", index_col= 0) 
df
# Out:
#          country  density abbreviation  agricultural_land  land_area  \
# 0    Afghanistan     60.0           AF               58.1    652.230
# 1        Albania    105.0           AL               43.1     28.748
# 2        Algeria     18.0           DZ               17.4        NaN
# 3        Andorra    164.0           AD               40.0    468.000
# 4         Angola     26.0           AO               47.5        NaN
# ..           ...      ...          ...                ...        ...
# 190    Venezuela     32.0           VE               24.5    912.050
# 191      Vietnam    314.0           VN               39.3    331.210
# 192        Yemen     56.0           YE               44.6    527.968
# 193       Zambia     25.0           ZM               32.1    752.618
# 194     Zimbabwe     38.0           ZW               41.9    390.757
#
#      armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0                323.0       32.49          93.0              Kabul
# ...

# %% [markdown]
# 1 ¿Cómo se distribuye la tasa de natalidad en el conjunto de datos? ¿Hay algún patrón evidente?

# %%
sns.histplot(x = "birth_rate", data = df, color = "violet", bins = 60);

# %%
df["birth_rate"].describe()
# Out:
# count    189.000000
# mean      20.214974
# std        9.945774
# min        5.900000
# 25%       11.300000
# 50%       17.950000
# 75%       28.750000
# max       46.080000
# Name: birth_rate, dtype: float64

# %%
sns.boxplot(x=df["birth_rate"])
# Out:
# <Axes: xlabel='birth_rate'>

# %%
# la tendencia sube a partir del 10%. Es decir, que en la mayoría de los países, la tasa de natalidad es del 10%

# %% [markdown]
# ¿Existe una relación aparente entre la tasa de mortalidad infantil y la esperanza de vida? Proporciona una breve descripción de los patrones que observes

# %%
df.head()
# Out:
#        country  density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan     60.0           AF               58.1    652.230
# 1      Albania    105.0           AL               43.1     28.748
# 2      Algeria     18.0           DZ               17.4        NaN
# 3      Andorra    164.0           AD               40.0    468.000
# 4       Angola     26.0           AO               47.5        NaN
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0              323.0       32.49          93.0              Kabul
# 1                9.0       11.78         355.0             Tirana
# 2              317.0       24.28         213.0            Algiers
# 3                NaN        7.20         376.0   Andorra la Vella
# 4              117.0       40.73         244.0             Luanda
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0          8.672  149.90         2.3           AFN            4.47
# ...

# %%
sns.regplot(x = "infant_mortality", 
            y = "life_expectancy", 
            data = df,
            color = "lightcoral")


plt.xlabel("Mortalidad Infantil")
plt.ylabel("Esperanza de Vida")

plt.title("Relación entre mortalidad y esperanza de vida");

# %%
df[["infant_mortality", "life_expectancy"]].describe()
# Out:
#        infant_mortality  life_expectancy
# count        189.000000       187.000000
# mean          21.332804        72.279679
# std           19.548058         7.483661
# min            1.400000        52.800000
# 25%            6.000000        67.000000
# 50%           14.000000        73.200000
# 75%           32.700000        77.500000
# max           84.500000        85.400000

# %%
# a menor tasa de mortalidad infantil, mayor es la expectativa de vida

# %% [markdown]
# ¿Cuál es la mediana de la esperanza de vida en Europa? Proporciona un rango intercuartil aproximado y verifica si existen valores atípicos.

# %%
sns.boxplot(x="continent", y="life_expectancy", data=df, color="springgreen")
plt.xticks(rotation=45)  
plt.show()

# %%
df[df["continent"] == "Europe"].describe().T

# la repsuesta es 79%
# Out:
#                                       count          mean           std  \
# density                                47.0  1.217813e+02  1.194589e+02
# agricultural_land                      44.0  3.995227e+01  1.759743e+01
# land_area                              46.0  1.706533e+02  1.925698e+02
# armed_forces_size                      40.0  7.930000e+01  1.154530e+02
# birth_rate                             45.0  9.955111e+00  1.774415e+00
# calling_code                           47.0  2.606383e+02  1.975273e+02
# co2-emissions                          42.0  1.087405e+02  1.568064e+02
# cpi                                    41.0  1.249485e+02  3.446754e+01
# cpi_change                             42.0  2.457143e+00  2.573897e+00
# fertility_rate                         44.0  1.537045e+00  2.023534e-01
# forested_area                          44.0  3.250909e+01  1.707631e+01
# gasoline_price                         44.0  1.295909e+00  2.959519e-01
# ...
